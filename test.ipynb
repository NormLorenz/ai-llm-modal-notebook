# %% [markdown]
# <a href="https://colab.research.google.com/github/NormLorenz/ai-llm-modal-notebook/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test Notebook
#
# Starter notebook created by GitHub Copilot Chat Assistant.

# %%
print('hello bobnnnknjnkj.jkn')
print('hello bobnnnknjnkj.jkn')
# Out:
# hello bobnnnknjnkj.jkn
# hello bobnnnknjnkj.jkn
